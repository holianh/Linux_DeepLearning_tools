# %%
import os;
GPUs="3"
gpus=1
os.environ["CUDA_VISIBLE_DEVICES"]=GPUs#"3" #"0,1,2"
import json
#import taLibs as ta
import numpy as np
from os.path import exists
import pickle;
from keras.models import Model;
from keras import backend as K;
from keras.layers.embeddings import Embedding;
#from keras.utils.vis_utils import plot_model;
from keras.models import Sequential, load_model,save_model;
from keras.optimizers import rmsprop, adam, adagrad, SGD;
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau;
from keras.preprocessing.text import text_to_word_sequence, one_hot, Tokenizer;
from keras.layers import Input, Dense, merge, Dropout, BatchNormalization, Activation, Conv1D, Lambda;
#from Levenshtein import distance
import matplotlib                                    ###############
matplotlib.use('agg')
import matplotlib.pyplot as plt   
from matplotlib.backends.backend_pdf import PdfPages ###############
import datetime as dt
from os.path import exists
import time,math
import fnmatch
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")
import pprint as pp

print()
print('########################################################################################################')
print('Start...')
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7034bd8e165e> in <module>()
#       8 from os.path import exists
#       9 import pickle;
# ---> 10 from keras.models import Model;
#      11 from keras import backend as K;
#      12 from keras.layers.embeddings import Embedding;
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/Keras-1.2.2-py3.5.egg/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
# ----> 2 from . import backend
#       3 from . import datasets
#       4 from . import engine
#       5 from . import layers
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/Keras-1.2.2-py3.5.egg/keras/backend/__init__.py in <module>()
#      65 elif _BACKEND == 'tensorflow':
#      66     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 67     from .tensorflow_backend import *
#      68 elif _BACKEND == 'mxnet':
#      69     sys.stderr.write('Using MXNet backend.\n')
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/Keras-1.2.2-py3.5.egg/keras/backend/tensorflow_backend.py in <module>()
# ----> 1 import tensorflow as tf
#       2
#       3 from tensorflow.python.training import moving_averages
#       4 from tensorflow.python.ops import tensor_array_ops
#       5 from tensorflow.python.ops import control_flow_ops
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/__init__.py in <module>()
#      21 from __future__ import print_function
#      22
# ---> 23 from tensorflow.python import *
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/python/__init__.py in <module>()
#      63 from tensorflow.core.util.event_pb2 import *
#      64 # Import things out of contrib
# ---> 65 import tensorflow.contrib as contrib
#      66
#      67 # Framework
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/__init__.py in <module>()
#      28 from tensorflow.contrib import grid_rnn
#      29 from tensorflow.contrib import layers
# ---> 30 from tensorflow.contrib import learn
#      31 from tensorflow.contrib import linear_optimizer
#      32 from tensorflow.contrib import lookup
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/__init__.py in <module>()
#      70
#      71 # pylint: disable=wildcard-import
# ---> 72 from tensorflow.contrib.learn.python.learn import *
#      73 from tensorflow.python.util.all_util import make_all
#      74
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/__init__.py in <module>()
#      21
#      22 # pylint: disable=wildcard-import
# ---> 23 from tensorflow.contrib.learn.python.learn import *
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/__init__.py in <module>()
#      24 # pylint: disable=wildcard-import
#      25 from tensorflow.contrib.learn.python.learn import datasets
# ---> 26 from tensorflow.contrib.learn.python.learn import estimators
#      27 from tensorflow.contrib.learn.python.learn import graph_actions
#      28 from tensorflow.contrib.learn.python.learn import learn_io as io
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/__init__.py in <module>()
#      21
#      22 from tensorflow.contrib.learn.python.learn.estimators._sklearn import NotFittedError
# ---> 23 from tensorflow.contrib.learn.python.learn.estimators.autoencoder import TensorFlowDNNAutoencoder
#      24 from tensorflow.contrib.learn.python.learn.estimators.base import TensorFlowBaseTransformer
#      25 from tensorflow.contrib.learn.python.learn.estimators.base import TensorFlowEstimator
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/autoencoder.py in <module>()
#      23
#      24 from tensorflow.contrib.learn.python.learn import models
# ---> 25 from tensorflow.contrib.learn.python.learn.estimators.base import TensorFlowBaseTransformer
#      26 from tensorflow.python.ops import nn
#      27
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/base.py in <module>()
#      32 from tensorflow.contrib import layers
#      33 from tensorflow.contrib.learn.python.learn.estimators import _sklearn
# ---> 34 from tensorflow.contrib.learn.python.learn.estimators import estimator
#      35 from tensorflow.contrib.learn.python.learn.estimators._sklearn import NotFittedError
#      36 from tensorflow.contrib.learn.python.learn.learn_io.data_feeder import setup_train_data_feeder
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/estimator.py in <module>()
#      37 from tensorflow.contrib.learn.python.learn.estimators import tensor_signature
#      38 from tensorflow.contrib.learn.python.learn.estimators._sklearn import NotFittedError
# ---> 39 from tensorflow.contrib.learn.python.learn.learn_io import data_feeder
#      40 from tensorflow.contrib.learn.python.learn.utils import checkpoints
#      41
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/learn_io/__init__.py in <module>()
#      20 from __future__ import print_function
#      21
# ---> 22 from tensorflow.contrib.learn.python.learn.learn_io.dask_io import extract_dask_data
#      23 from tensorflow.contrib.learn.python.learn.learn_io.dask_io import extract_dask_labels
#      24 from tensorflow.contrib.learn.python.learn.learn_io.dask_io import HAS_DASK
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/learn_io/dask_io.py in <module>()
#      24 try:
#      25   # pylint: disable=g-import-not-at-top
# ---> 26   import dask.dataframe as dd
#      27   allowed_classes = (dd.Series, dd.DataFrame)
#      28   HAS_DASK = True
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/dask/dataframe/__init__.py in <module>()
# ----> 1 from .core import (DataFrame, Series, Index, _Frame, map_partitions,
#       2                    repartition)
#       3 from .io import (read_csv, from_array, from_bcolz, from_array, from_bcolz,
#       4                  from_pandas, from_dask_array, from_castra, read_hdf,
#       5                  from_imperative)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/dask/dataframe/core.py in <module>()
#      21     Cache = dict
#      22
# ---> 23 from .. import array as da
#      24 from .. import core
#      25 from ..array.core import partial_by_order
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/dask/array/__init__.py in <module>()
#       2
#       3 from ..utils import ignoring
# ----> 4 from .core import (Array, stack, concatenate, take, tensordot, transpose,
#       5         from_array, from_imperative, choose, where, coarsen, insert,
#       6         broadcast_to, ravel, reshape, fromfunction, unique, store, squeeze,
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/dask/array/core.py in <module>()
#      11 from functools import partial, wraps
#      12
# ---> 13 from toolz.curried import (pipe, partition, concat, unique, pluck, join, first,
#      14                            memoize, map, groupby, valmap, accumulate, merge,
#      15                            curry, reduce, interleave, sliding_window, partial)
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/toolz/curried/__init__.py in <module>()
#      51
#      52 locals().update(toolz.merge(
# ---> 53     _curry_namespace(vars(toolz)),
#      54     _curry_namespace(vars(exceptions)),
#      55 ))
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/toolz/curried/__init__.py in _curry_namespace(ns)
#      46     return dict(
#      47         (name, toolz.curry(f) if _should_curry(f) else f)
# ---> 48         for name, f in ns.items() if '__' not in name
#      49     )
#      50
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/toolz/curried/__init__.py in <genexpr>(.0)
#      46     return dict(
#      47         (name, toolz.curry(f) if _should_curry(f) else f)
# ---> 48         for name, f in ns.items() if '__' not in name
#      49     )
#      50
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/toolz/curried/__init__.py in _should_curry(f)
#      40 def _should_curry(f):
#      41     do_curry = frozenset((toolz.map, toolz.filter, toolz.sorted, toolz.reduce))
# ---> 42     return (callable(f) and _nargs(f) > 1 or f in do_curry)
#      43
#      44
#
# /home/ubuntu/anaconda3/lib/python3.5/site-packages/toolz/curried/__init__.py in _nargs(f)
#      33 def _nargs(f):
#      34     try:
# ---> 35         return len(inspect.getargspec(f).args)
#      36     except TypeError:
#      37         return 0
#
# /home/ubuntu/anaconda3/lib/python3.5/inspect.py in getargspec(func)
#    1048         getfullargspec(func)
#    1049     if kwonlyargs or ann:
# -> 1050         raise ValueError("Function has keyword-only arguments or annotations"
#    1051                          ", use getfullargspec() API which can support them")
#    1052     return ArgSpec(args, varargs, varkw, defaults)
#
# ValueError: Function has keyword-only arguments or annotations, use getfullargspec() API which can support them

# %%
model=load_model(Client_filepath_BestModel,compile=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ae8b4419eab> in <module>()
# ----> 1 model=load_model(Client_filepath_BestModel,compile=False)
#
# NameError: name 'load_model' is not defined
